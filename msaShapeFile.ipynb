# %%
import geopandas as gpd

# %%
base_path = "/Users/tinazhang/Downloads/"
msa_shapefile = gpd.read_file(base_path + "tl_2024_us_cbsa/tl_2024_us_cbsa.shx")

# %%
msa_shapefile.plot()
# Out:
# <Axes: >
